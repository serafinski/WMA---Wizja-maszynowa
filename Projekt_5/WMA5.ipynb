# %%
# Najpierw preparatyka danych na Roboflow
https://app.roboflow.com/pro5/wma5/browse?queryText=&pageSize=50&startingIndex=0&browseQuery=true

# %%
# Instalacja wymaganych zasobów
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -qr requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5/yolov5/yolov5

# %%
# Ściągniecie danych
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="<insert-key-here>")
project = rf.workspace("pro5").project("wma5")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd /content/yolov5
# %cat {dataset.location}/data.yaml
# Out:
# /content/yolov5
# names:
# - candle
# - controller
# - pillow
# - sunglasses
# nc: 4
# roboflow:
#   license: MIT
#   project: wma5
#   url: https://universe.roboflow.com/pro5/wma5/dataset/1
#   version: 1
#   workspace: pro5
# test: ../test/images
# train: WMA5-1/train/images
# val: WMA5-1/valid/images

# %%
# Trenining
# !python train.py --img 640 --batch 16 --epochs 300 --data {dataset.location}/data.yaml --weights 'yolov5s.pt' --name test2 --cache
# Out:
# 2024-05-31 17:20:09.414502: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-31 17:20:09.414561: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-31 17:20:09.416150: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Podmontowanie dysku
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ścieżki do wideo
input_video_path = '/content/drive/MyDrive/IMG_3924.mp4'
weights_path = '/content/yolov5/runs/train/test2/weights/best.pt'
output_dir = '/content/yolov5/runs/detect'
output_name = 'test2'

# Odpalenie detekcji
# !python detect.py --weights {weights_path} --source {input_video_path} --project {output_dir} --name {output_name} --save-txt --save-conf

# Output
import glob
output_video_path = glob.glob(f'{output_dir}/{output_name}/*.mp4')[0]

# Zapis do dysku
drive_output_path = '/content/drive/MyDrive/output3.mp4'
# !cp {output_video_path} {drive_output_path}

print(f"Processed video saved to: {drive_output_path}")
# Out:
# detect: weights=['/content/yolov5/runs/train/test2/weights/best.pt'], source=/content/drive/MyDrive/IMG_3924.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/yolov5/runs/detect, name=test2, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-318-gc0380fd8 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/709) /content/drive/MyDrive/IMG_3924.mp4: 640x384 1 controller, 2 pillows, 53.0ms
# video 1/1 (2/709) /content/drive/MyDrive/IMG_3924.mp4: 640x384 1 controller, 1 pillow, 10.5ms
# ...

# %%
# Trenining na losowych wagach
# !python train.py --img 640 --batch 16 --epochs 300 --data {dataset.location}/data.yaml --weights '' --cfg yolov5s.yaml --name test2_random --cache
# Out:
# 2024-05-31 17:46:53.403518: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-31 17:46:53.403575: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-31 17:46:53.405040: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Ścieżki do wideo
input_video_path = '/content/drive/MyDrive/IMG_3924.mp4'
weights_path = '/content/yolov5/runs/train/test2_random/weights/best.pt'
output_dir = '/content/yolov5/runs/detect'
output_name = 'test2_random'

# Odpalenie detekcji
# !python detect.py --weights {weights_path} --source {input_video_path} --project {output_dir} --name {output_name} --save-txt --save-conf

# Output
import glob
output_video_path = glob.glob(f'{output_dir}/{output_name}/*.mp4')[0]

# Zapis do dysku
drive_output_path = '/content/drive/MyDrive/output3_random.mp4'
# !cp {output_video_path} {drive_output_path}

print(f"Processed video saved to: {drive_output_path}")
# Out:
# detect: weights=['/content/yolov5/runs/train/test2_random/weights/best.pt'], source=/content/drive/MyDrive/IMG_3924.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/yolov5/runs/detect, name=test2_random, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-318-gc0380fd8 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/709) /content/drive/MyDrive/IMG_3924.mp4: 640x384 (no detections), 55.5ms
# video 1/1 (2/709) /content/drive/MyDrive/IMG_3924.mp4: 640x384 (no detections), 10.5ms
# ...
